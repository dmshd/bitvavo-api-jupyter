# %%
import pandas as pd
from python_bitvavo_api.bitvavo import Bitvavo

# %%
bitvavo = Bitvavo()
response = bitvavo.publicTrades('BTC-EUR', {})
for trade in response:
  print(trade)
# Out:
# {'id': 'd36c8931-fa98-4cf8-82a2-50c02718b79e', 'timestamp': 1615748893722, 'amount': '0.00381051', 'price': '49862', 'side': 'buy'}
# {'id': 'e3a402cc-cefd-4149-9f6d-2a456deea272', 'timestamp': 1615748892290, 'amount': '0.00398797', 'price': '49862', 'side': 'buy'}
# {'id': '2c7e7649-3cfd-487d-b1d9-32baedf0be8e', 'timestamp': 1615748892277, 'amount': '0.00601203', 'price': '49861', 'side': 'buy'}
# {'id': 'cc5fc827-63cc-44b5-9b06-c45a7f775303', 'timestamp': 1615748892102, 'amount': '0.0000104', 'price': '49861', 'side': 'buy'}
# {'id': '38b1d634-1b4a-4dc8-b2e5-678bcb647b8e', 'timestamp': 1615748891742, 'amount': '0.00200057', 'price': '49861', 'side': 'buy'}
# {'id': 'ff75cf69-b253-4767-a831-2a5f86b37b98', 'timestamp': 1615748890468, 'amount': '0.00159264', 'price': '49862', 'side': 'buy'}
# {'id': '512879a6-75f9-4248-891e-39216567a0ad', 'timestamp': 1615748890459, 'amount': '0.0188256', 'price': '49860', 'side': 'buy'}
# ...

# %%
trades = pd.DataFrame(response)
trades
# Out:
#                                        id      timestamp      amount  price  \
# 0    d36c8931-fa98-4cf8-82a2-50c02718b79e  1615748893722  0.00381051  49862
# 1    e3a402cc-cefd-4149-9f6d-2a456deea272  1615748892290  0.00398797  49862
# 2    2c7e7649-3cfd-487d-b1d9-32baedf0be8e  1615748892277  0.00601203  49861
# 3    cc5fc827-63cc-44b5-9b06-c45a7f775303  1615748892102   0.0000104  49861
# 4    38b1d634-1b4a-4dc8-b2e5-678bcb647b8e  1615748891742  0.00200057  49861
# ..                                    ...            ...         ...    ...
# 495  a6dc673a-c8b6-4a23-866f-ee884ea90c2f  1615748248521  0.00180221  49935
# 496  71c6795b-d74a-4d6f-90e2-55079895ecaf  1615748248478  0.00240523  49932
# 497  6ec807b0-e0d8-49fe-a3cb-03708ac012e7  1615748247974  0.00340741  49934
# 498  1a5b0319-033e-461d-a0d8-ae9d7de5f84c  1615748247295   0.0010013  49935
# 499  76336c51-9023-4af6-b059-43ac5ada4c19  1615748245944  0.00180234  49935
#
#      side
# 0     buy
# 1     buy
# 2     buy
# ...
